# %%
import os
import tifffile
import numpy
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/song676/p4m'

# %%
### RAW

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0041.TIF')))
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0051.TIF')))
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0061.TIF')))
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0071.TIF')))
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0081.TIF')))
plt.colorbar()

# %%
### REFLECTANCE

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0041.TIF'))/2**16)
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0051.TIF'))/2**16)
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0061.TIF'))/2**16)
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0071.TIF'))/2**16)
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0081.TIF'))/2**16)
plt.colorbar()

# %%
### REFLECTANCE with Filtering

# %%
DJI_0041 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0041.TIF'))/2**16
DJI_0051 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0051.TIF'))/2**16
DJI_0061 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0061.TIF'))/2**16
DJI_0071 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0071.TIF'))/2**16
DJI_0081 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0081.TIF'))/2**16

DJI_0041[DJI_0041>0.1]=0
DJI_0051[DJI_0051>0.1]=0
DJI_0061[DJI_0061>0.1]=0
DJI_0071[DJI_0071>0.1]=0
DJI_0081[DJI_0081>0.1]=0

# %%
plt.imshow(DJI_0041)
plt.colorbar()

# %%
plt.imshow(DJI_0051)
plt.colorbar()

# %%
plt.imshow(DJI_0061)
plt.colorbar()

# %%
plt.imshow(DJI_0071)
plt.colorbar()

# %%
plt.imshow(DJI_0081)
plt.colorbar()
