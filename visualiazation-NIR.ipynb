# %%
import os
import tifffile
import numpy
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/song676/p4m'

# %%
### RAW

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0045.TIF')))
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0055.TIF')))
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0065.TIF')))
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0075.TIF')))
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'raw', 'DJI_0085.TIF')))
plt.colorbar()

# %%
### REFLECTANCE

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0045.TIF'))/2**16)
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0055.TIF'))/2**16)
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0065.TIF'))/2**16)
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0075.TIF'))/2**16)
plt.colorbar()

# %%
plt.imshow(tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0085.TIF'))/2**16)
plt.colorbar()

# %%
### REFLECTANCE with Filtering

# %%
DJI_0045 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0045.TIF'))/2**16
DJI_0055 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0055.TIF'))/2**16
DJI_0065 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0065.TIF'))/2**16
DJI_0075 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0075.TIF'))/2**16
DJI_0085 = tifffile.imread(os.path.join(os.getcwd(),'ref', 'DJI_0085.TIF'))/2**16

DJI_0045[DJI_0045>0.25]=0
DJI_0055[DJI_0055>0.25]=0
DJI_0065[DJI_0065>0.25]=0
DJI_0075[DJI_0075>0.25]=0
DJI_0085[DJI_0085>0.25]=0

# %%
plt.imshow(DJI_0045)
plt.colorbar()

# %%
plt.imshow(DJI_0055)
plt.colorbar()

# %%
plt.imshow(DJI_0065)
plt.colorbar()

# %%
plt.imshow(DJI_0075)
plt.colorbar()

# %%
plt.imshow(DJI_0085)
plt.colorbar()
